# %%
import pandas as pd

# %%
df=pd.read_csv("regions_table.csv")

# %%
df
# Out:
#      Region_Name  Region_ID
# 0          India          1
# 1            SEA          2
# 2         Europe          3
# 3  North America          4
# 4    Middle East          5

# %%
df.head()
# Out:
#      Region_Name  Region_ID
# 0          India          1
# 1            SEA          2
# 2         Europe          3
# 3  North America          4
# 4    Middle East          5

# %%
df.tail()
# Out:
#      Region_Name  Region_ID
# 0          India          1
# 1            SEA          2
# 2         Europe          3
# 3  North America          4
# 4    Middle East          5

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Region_Name  Region_ID
# 0          India          1
# 1            SEA          2
# 2         Europe          3
# 3  North America          4
# 4    Middle East          5>

# %%
df.shape
# Out:
# (5, 2)

# %%
df.sample()
# Out:
#   Region_Name  Region_ID
# 0       India          1

# %%
df.dtypes
# Out:
# Region_Name    object
# Region_ID       int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      Region_Name  Region_ID
# 0          India          1
# 1            SEA          2
# 2         Europe          3
# 3  North America          4
# 4    Middle East          5>

# %%
df.to_csv("C:/Users/Bala Ganesh/Documents/cleaned_regions_table.csv", index=False)
print("Cleaned data saved as 'cleaned_regions_table.csv")
# Out:
# Cleaned data saved as 'cleaned_regions_table.csv
